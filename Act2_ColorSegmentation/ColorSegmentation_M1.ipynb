# %%
import matplotlib.pyplot as plt
import numpy as np 
from matplotlib import cm 
from matplotlib import colors
from matplotlib.colors import hsv_to_rgb
import cv2

# %%
img = cv2.imread('bags.png')
#img = cv2.imread('img.jpg')
plt.imshow(img)
plt.show()

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
r,g,b = cv2.split(img)
fig = plt.figure()
axis = fig.add_subplot(1,1,1, projection = "3d")
pixel_colors = img.reshape((np.shape(img)[0]*np.shape(img)[1],3))
norm = colors.Normalize(vmin = 1., vmax = 1.)
norm.autoscale(pixel_colors)
pixel_colors = norm(pixel_colors).tolist()
axis.scatter(r.flatten(), g.flatten(), b.flatten(), facecolors = pixel_colors, marker = ".")
axis.set_xlabel= ("Red")
axis.set_ylabel= ("Green")
axis.set_zlabel= ("Blue")
plt.show()

# %%
hsv_img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
h, s, v = cv2.split(hsv_img)
fig = plt.figure()
axis = fig.add_subplot(1,1,1, projection = "3d")
axis.scatter(h.flatten(), s.flatten(), v.flatten(), facecolors = pixel_colors, marker = ".")
axis.set_xlabel= ("Hue")
axis.set_ylabel= ("Saturation")
axis.set_zlabel= ("Value")
plt.show()

# %%
light_yellow = (51, 255, 255)
dark_yellow = (25, 130, 120)


lo_square = np.full((10,10,3), light_yellow, dtype=np.uint8) / 255.0
do_square = np.full((10,10,3), dark_yellow, dtype=np.uint8) / 255.0
plt.subplot(1,2,1)
plt.imshow(hsv_to_rgb(lo_square))
plt.subplot(1,2,2)
plt.imshow(hsv_to_rgb(do_square))
plt.show()

# %%
mask = cv2.inRange(hsv_img, dark_yellow, light_yellow)
result_yellow = cv2.bitwise_and(img, img, mask=mask)
plt.subplot(1,2,1)
plt.imshow(mask, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result_yellow)
plt.show()

# %%
light_green = (100, 255, 178)
dark_green = (76, 102, 51)

lo_square = np.full((10,10,3), light_green, dtype=np.uint8) / 255.0
do_square = np.full((10,10,3), dark_green, dtype=np.uint8) / 255.0
plt.subplot(1,2,1)
plt.imshow(hsv_to_rgb(lo_square))
plt.subplot(1,2,2)
plt.imshow(hsv_to_rgb(do_square))
plt.show()

# %%
mask = cv2.inRange(hsv_img, dark_green, light_green)
result_green = cv2.bitwise_and(img, img, mask=mask)
plt.subplot(1,2,1)
plt.imshow(mask, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result_green)
plt.show()

# %%
light_blue = (178, 255, 255)
dark_blue = (100, 127, 63)


lo_square = np.full((10,10,3), light_blue, dtype=np.uint8) / 255.0
do_square = np.full((10,10,3), dark_blue, dtype=np.uint8) / 255.0
plt.subplot(1,2,1)
plt.imshow(hsv_to_rgb(lo_square))
plt.subplot(1,2,2)
plt.imshow(hsv_to_rgb(do_square))
plt.show()

# %%
mask = cv2.inRange(hsv_img, dark_blue, light_blue)
result_blue = cv2.bitwise_and(img, img, mask=mask)
plt.subplot(1,2,1)
plt.imshow(mask, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result_blue)
plt.show()

# %%
light_orange = (12, 255, 255)
dark_orange = (0, 127, 120)

lo_square = np.full((10,10,3), light_orange, dtype=np.uint8) / 255.0
do_square = np.full((10,10,3), dark_orange, dtype=np.uint8) / 255.0
plt.subplot(1,2,1)
plt.imshow(hsv_to_rgb(lo_square))
plt.subplot(1,2,2)
plt.imshow(hsv_to_rgb(do_square))
plt.show()

# %%
mask = cv2.inRange(hsv_img, dark_orange, light_orange)
result_orange = cv2.bitwise_and(img, img, mask=mask)
plt.subplot(1,2,1)
plt.imshow(mask, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result_orange)
plt.show()

# %%
light_total = (255, 255, 255)
dark_total = (0, 102, 25)

lo_square = np.full((10,10,3), light_total, dtype=np.uint8) / 255.0
do_square = np.full((10,10,3), dark_total, dtype=np.uint8) / 255.0
plt.subplot(1,2,1)
plt.imshow(hsv_to_rgb(lo_square))
plt.subplot(1,2,2)
plt.imshow(hsv_to_rgb(do_square))
plt.show()

# %%
mask = cv2.inRange(hsv_img, dark_total, light_total)
result_total = cv2.bitwise_and(img, img, mask=mask)
plt.subplot(1,2,1)
plt.imshow(mask, cmap="gray")
plt.subplot(1,2,2)
plt.imshow(result_total)
plt.show()
